# %% [markdown]
# # Read the dataset to python environment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
auto_data = pd.read_excel(r'C:\Users\PREM\Downloads\iris.xls')
auto_data.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
auto_data.shape
# Out:
# (150, 5)

# %% [markdown]
# # Display the columns in the dataset

# %%
auto_data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # Check for the null values present in the dataset.

# %%
auto_data.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# # Calculate the mean of each column of the dataset

# %%
data = auto_data[['SL','SW','PL','PW']].mean()
print(data)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # Perform meaningful visualizations using the dataset

# %%
#using Seaborn

# %%
sns.pairplot(auto_data)

# %%
# using Histogram

# %%
plt.hist(auto_data['SL'],color ='g',rwidth =0.80)
plt.title('PL of Iris',fontsize =30)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.figure(figsize=(10,8))
plt.show()

# %%
# USING bOXPLOT

# %%
plt.boxplot(auto_data['SL'])
plt.show()

# %%
plt.boxplot(auto_data['SW'])
plt.show()

# %%
plt.boxplot(auto_data['PL'])
plt.show()

# %%
plt.boxplot(auto_data['PW'])
plt.show()
